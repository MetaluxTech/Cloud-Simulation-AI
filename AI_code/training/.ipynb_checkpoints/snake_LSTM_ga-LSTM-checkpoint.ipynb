# %%
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
import pandas as pd
import tensorflow as tf
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from keras.models import Sequential,load_model
from keras.layers import LSTM, Dense,Dropout,Bidirectional
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
# Out:
# WARNING:tensorflow:From d:\cloudsim_finall\AI_code\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv('../dataset/global_dataset.csv')

df.drop(columns=['TaskID','VmID'], inplace=True)  # Features


X = df.drop(['DataCenterID'], axis=1)  # Features
y = df['DataCenterID']-3  # Label

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
unique_labels = np.unique(y_train.values)
print(unique_labels)
print(df.info())
num_classes = len(unique_labels)
# Out:
# [0 1 2]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   TaskFileSize           2000 non-null   int64
#  1   TaskOutputFileSize     2000 non-null   int64
#  2   TaskFileLength         2000 non-null   int64
#  3   CpuTime                2000 non-null   float64
#  4   TotalLength            2000 non-null   int64
#  5   UserLatitude           2000 non-null   float64
#  6   UserLongitude          2000 non-null   float64
#  7   DataCenterID           2000 non-null   int64
#  8   ENSEMBLE_predicted_DC  2000 non-null   int64
#  9   GA_predicted_DC        2000 non-null   int64
#  10  SNAKE_predicted_DC     2000 non-null   int64
#  11  SNAKE_predicted_VM     2000 non-null   int64
#  12  ENSEMBLE_predicted_VM  2000 non-null   int64
# dtypes: float64(3), int64(10)
# memory usage: 203.2 KB
# None

# %%
# sns.pairplot(df, hue='DataCenterID')
# plt.show()

# %%
data_center_labels = ['DataCenter1', 'DataCenter2', 'DataCenter3']
tasks_per_data_center = df['DataCenterID'].value_counts().sort_index()

# Assigning colors
colors = ['skyblue', 'lightgreen', 'lightcoral']

# Plotting
fig, ax = plt.subplots()
bars = ax.bar(data_center_labels, tasks_per_data_center, color=colors)

# Displaying the task counts on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Adjusting plot properties
plt.title('Task Distribution On DataCenters')
plt.xlabel('Data Centers')
plt.ylabel('Number of Tasks')
plt.ylim(0, max(tasks_per_data_center) + 50)  # Adjust y-axis limit for better visibility
plt.show()

# %%
if (len(X_train.shape)<3):
    X_train = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_test = X_test.values.reshape((X_test.shape[0], 1, X_test.shape[1]))

print(" xtrain ", X_train.shape, "\n", "ytrain ", y_train.shape, "\n", "xtest  ", X_test.shape, "\n", "ytest ", y_test.shape, "\n")
# Out:
#  xtrain  (1600, 1, 12)
#  ytrain  (1600,)
#  xtest   (400, 1, 12)
#  ytest  (400,)

# %%
def trainModel(hyperparameters):
    # Build and train the model
    model = Sequential()
    model.add(LSTM(units=int(hyperparameters['units']), input_shape=(1, X_train.shape[2]), return_sequences=True))
    model.add(Dropout(hyperparameters['dropout_rate']))
    model.add(LSTM(units=int(hyperparameters['units']) // 2))
    model.add(Dense(units=num_classes, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=hyperparameters['learning_rate']),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    hist = model.fit(X_train, y_train,
                        epochs=hyperparameters['epochs'],
                        batch_size=int(hyperparameters['batch_size']),
                        validation_data=(X_test, y_test),
                       )
    return model,hist
SNAKE_hyperparameters = {'units': 128, 'dropout_rate': 0.01, 'learning_rate': 0.001, 'batch_size': 32,'epochs':100}
GA_hyperparameters =   {'units': 70.04564, 'dropout_rate': 0.1, 'learning_rate': 0.0021, 'batch_size': 21,'epochs':100}   

ga_model,ga_hist= trainModel(GA_hyperparameters)
ga_accuracy = max(ga_hist.history["accuracy"])

snake_model,snake_hist= trainModel(SNAKE_hyperparameters)
snake_accuracy = max(snake_hist.history["accuracy"])
# Out:
# Epoch 1/100
# 77/77 [==============================] - 11s 26ms/step - loss: 0.7081 - accuracy: 0.7269 - val_loss: 0.4964 - val_accuracy: 0.7725
# Epoch 2/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0
100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3311 - accuracy: 0.8587 - val_loss: 0.3505 - val_accuracy: 0.8425
# Epoch 29/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3124 - accuracy: 0.8656 - val_loss: 0.3650 - val_accuracy: 0.8350
# Epoch 30/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3000 - accuracy: 0.8819 - val_loss: 0.3497 - val_accuracy: 0.8350
# Epoch 31/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3152 - accuracy: 0.8656 - val_loss: 0.3353 - val_accuracy: 0.8525
# Epoch 32/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.2995 - accuracy: 0.8763 - val_loss: 0.3943 - val_accuracy: 0.8200
# Epoch 33/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.2961 - accuracy: 0.8781 - val_loss: 0.3603 - val_accuracy: 0.8300
# Epoch 34/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3106 - accuracy: 0.8706 - val_loss: 0.3757 - val_accuracy: 0.8375
# Epoch 35/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.3094 - accuracy: 0.8794 - val_loss: 0.3407 - val_accuracy: 0.8400
# Epoch 36/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.2876 - accuracy: 0.8838 - val_loss: 0.3467 - val_accuracy: 0.8475
# Epoch 37/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.3016 - accuracy: 0.8744 - val_loss: 0.3445 - val_accuracy: 0.8550
# Epoch 38/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2904 - accuracy: 0.8763 - val_loss: 0.3813 - val_accuracy: 0.8475
# Epoch 39/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2865 - accuracy: 0.8819 - val_loss: 0.3395 - val_accuracy: 0.8500
# Epoch 40/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2915 - accuracy: 0.8806 - val_loss: 0.3309 - val_accuracy: 0.8600
# Epoch 41/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.2948 - accuracy: 0.8737 - val_loss: 0.3258 - val_accuracy: 0.8525
# Epoch 42/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.2775 - accuracy: 0.8850 - val_loss: 0.3293 - val_accuracy: 0.8550
# Epoch 43/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.2741 - accuracy: 0.8875 - val_loss: 0.3388 - val_accuracy: 0.8450
# Epoch 44/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2748 - accuracy: 0.8900 - val_loss: 0.3539 - val_accuracy: 0.8475
# Epoch 45/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2813 - accuracy: 0.8856 - val_loss: 0.3389 - val_accuracy: 0.8450
# Epoch 46/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.3019 - accuracy: 0.8750 - val_loss: 0.3271 - val_accuracy: 0.8500
# Epoch 47/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2836 - accuracy: 0.8750 - val_loss: 0.3381 - val_accuracy: 0.8525
# Epoch 48/100
# 77/77 [==============================] - 0s 7ms/step - loss: 0.2778 - accuracy: 0.8875 - val_loss: 0.3368 - val_accuracy: 0.8575
# Epoch 49/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2759 - accuracy: 0.8831 - val_loss: 0.3623 - val_accuracy: 0.8400
# Epoch 50/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2656 - accuracy: 0.8881 - val_loss: 0.3571 - val_accuracy: 0.8525
# Epoch 51/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.2634 - accuracy: 0.8938 - val_loss: 0.3242 - val_accuracy: 0.8575
# Epoch 52/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2618 - accuracy: 0.8919 - val_loss: 0.3308 - val_accuracy: 0.8575
# Epoch 53/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.2611 - accuracy: 0.8956 - val_loss: 0.3496 - val_accuracy: 0.8400
# Epoch 54/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.2711 - accuracy: 0.8881 - val_loss: 0.3130 - val_accuracy: 0.8550
# Epoch 55/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.2479 - accuracy: 0.8975 - val_loss: 0.3489 - val_accuracy: 0.8475
# Epoch 56/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.2372 - accuracy: 0.9025 - val_loss: 0.3468 - val_accuracy: 0.8500
# Epoch 57/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2542 - accuracy: 0.8900 - val_loss: 0.3422 - val_accuracy: 0.8550
# Epoch 58/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2464 - accuracy: 0.8900 - val_loss: 0.3375 - val_accuracy: 0.8575
# Epoch 59/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.
100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2059 - accuracy: 0.9131 - val_loss: 0.3236 - val_accuracy: 0.8825
# Epoch 89/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.2071 - accuracy: 0.9175 - val_loss: 0.3418 - val_accuracy: 0.8575
# Epoch 90/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.2171 - accuracy: 0.9025 - val_loss: 0.3934 - val_accuracy: 0.8400
# Epoch 91/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2032 - accuracy: 0.9137 - val_loss: 0.3289 - val_accuracy: 0.8700
# Epoch 92/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.1947 - accuracy: 0.9187 - val_loss: 0.3349 - val_accuracy: 0.8725
# Epoch 93/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2160 - accuracy: 0.9075 - val_loss: 0.3657 - val_accuracy: 0.8575
# Epoch 94/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.2126 - accuracy: 0.9044 - val_loss: 0.3380 - val_accuracy: 0.8775
# Epoch 95/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2153 - accuracy: 0.9112 - val_loss: 0.3983 - val_accuracy: 0.8575
# Epoch 96/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2192 - accuracy: 0.9044 - val_loss: 0.3478 - val_accuracy: 0.8675
# Epoch 97/100
# 77/77 [==============================] - 1s 8ms/step - loss: 0.2117 - accuracy: 0.9112 - val_loss: 0.3790 - val_accuracy: 0.8600
# Epoch 98/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2199 - accuracy: 0.9094 - val_loss: 0.3101 - val_accuracy: 0.8850
# Epoch 99/100
# 77/77 [==============================] - 1s 7ms/step - loss: 0.1941 - accuracy: 0.9112 - val_loss: 0.3273 - val_accuracy: 0.8650
# Epoch 100/100
# 77/77 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.9106 - val_loss: 0.3465 - val_accuracy: 0.8575
# Epoch 1/100
# 50/50 [==============================] - 6s 32ms/step - loss: 0.7282 - accuracy: 0.7125 - val_loss: 0.5103 - val_accuracy: 0.7825
# Epoch 2/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4825 - accuracy: 0.8087 - val_loss: 0.4699 - val_accuracy: 0.7925
# Epoch 3/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.4300 - accuracy: 0.8250 - val_loss: 0.4388 - val_accuracy: 0.8025
# Epoch 4/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.4061 - accuracy: 0.8256 - val_loss: 0.4101 - val_accuracy: 0.8025
# Epoch 5/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3777 - accuracy: 0.8431 - val_loss: 0.4072 - val_accuracy: 0.8050
# Epoch 6/100
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3777 - accuracy: 0.8406 - val_loss: 0.3979 - val_accuracy: 0.8250
# Epoch 7/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3644 - accuracy: 0.8550 - val_loss: 0.3973 - val_accuracy: 0.8200
# Epoch 8/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3554 - accuracy: 0.8531 - val_loss: 0.4030 - val_accuracy: 0.8425
# Epoch 9/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3434 - accuracy: 0.8612 - val_loss: 0.3881 - val_accuracy: 0.8125
# Epoch 10/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3335 - accuracy: 0.8594 - val_loss: 0.4123 - val_accuracy: 0.8175
# Epoch 11/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3219 - accuracy: 0.8631 - val_loss: 0.3817 - val_accuracy: 0.8325
# Epoch 12/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3130 - accuracy: 0.8631 - val_loss: 0.4001 - val_accuracy: 0.8250
# Epoch 13/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3070 - accuracy: 0.8750 - val_loss: 0.3956 - val_accuracy: 0.8325
# Epoch 14/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3105 - accuracy: 0.8775 - val_loss: 0.3820 - val_accuracy: 0.8225
# Epoch 15/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2905 - accuracy: 0.8769 - val_loss: 0.4221 - val_accuracy: 0.8200
# Epoch 16/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.3015 - accuracy: 0.8744 - val_loss: 0.3875 - val_accuracy: 0.8225
# Epoch 17/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.2826 - accuracy: 0.8744 - val_loss: 0.4150 - val_accuracy: 0.8150
# Epoch 18/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.
100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0720 - accuracy: 0.9725 - val_loss: 0.4687 - val_accuracy: 0.8450
# Epoch 81/100
# 50/50 [==============================] - 1s 10ms/step - loss: 0.0772 - accuracy: 0.9681 - val_loss: 0.5246 - val_accuracy: 0.8350
# Epoch 82/100
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0772 - accuracy: 0.9706 - val_loss: 0.4957 - val_accuracy: 0.8450
# Epoch 83/100
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0652 - accuracy: 0.9794 - val_loss: 0.5479 - val_accuracy: 0.8375
# Epoch 84/100
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0996 - accuracy: 0.9550 - val_loss: 0.5695 - val_accuracy: 0.8325
# Epoch 85/100
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1135 - accuracy: 0.9600 - val_loss: 0.6377 - val_accuracy: 0.8325
# Epoch 86/100
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1271 - accuracy: 0.9550 - val_loss: 0.4822 - val_accuracy: 0.8575
# Epoch 87/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.1051 - accuracy: 0.9613 - val_loss: 0.4858 - val_accuracy: 0.8425
# Epoch 88/100
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0964 - accuracy: 0.9556 - val_loss: 0.4535 - val_accuracy: 0.8550
# Epoch 89/100
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0727 - accuracy: 0.9706 - val_loss: 0.5174 - val_accuracy: 0.8450
# Epoch 90/100
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0619 - accuracy: 0.9744 - val_loss: 0.5011 - val_accuracy: 0.8500
# Epoch 91/100
# 50/50 [==============================] - 1s 10ms/step - loss: 0.0684 - accuracy: 0.9769 - val_loss: 0.5582 - val_accuracy: 0.8625
# Epoch 92/100
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0892 - accuracy: 0.9613 - val_loss: 0.5537 - val_accuracy: 0.8425
# Epoch 93/100
# 50/50 [==============================] - 1s 12ms/step - loss: 0.0758 - accuracy: 0.9744 - val_loss: 0.5239 - val_accuracy: 0.8575
# Epoch 94/100
# 50/50 [==============================] - 1s 10ms/step - loss: 0.0573 - accuracy: 0.9775 - val_loss: 0.5010 - val_accuracy: 0.8650
# Epoch 95/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0731 - accuracy: 0.9712 - val_loss: 0.5477 - val_accuracy: 0.8525
# Epoch 96/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0602 - accuracy: 0.9825 - val_loss: 0.5340 - val_accuracy: 0.8500
# Epoch 97/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0538 - accuracy: 0.9819 - val_loss: 0.5855 - val_accuracy: 0.8500
# Epoch 98/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0709 - accuracy: 0.9731 - val_loss: 0.5705 - val_accuracy: 0.8525
# Epoch 99/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0744 - accuracy: 0.9700 - val_loss: 0.5657 - val_accuracy: 0.8425
# Epoch 100/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0859 - accuracy: 0.9663 - val_loss: 0.6247 - val_accuracy: 0.8350

# %%
print("snake  Accuracy: ",np.round(snake_accuracy* 100) ,'%')
print("GA Accuracy: ",np.round(ga_accuracy* 100) ,'%')
# Out:
# snake  Accuracy:  98.0 %
# GA Accuracy:  92.0 %

# %%
plt.plot(ga_hist.history['accuracy'])
plt.plot(snake_hist.history['accuracy'])
plt.title('GA vs SNAKE Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['GA', 'SNAKE'], loc='lower right')
plt.show()

plt.plot(ga_hist.history['loss'])
plt.plot(snake_hist.history['loss'])
plt.title('GA vs SNAKE Training Losses')
plt.xlabel('Epoch')
plt.ylabel('LOSS')
plt.legend(['GA', 'SNAKE'], loc='upper right')
plt.show()

print("\n\nGentic model summary")
print(ga_model.summary())
print("\n\nSnake model summary")
print(snake_model.summary())
# Out:
# Gentic model summary
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 70)             23240
#
#  dropout (Dropout)           (None, 1, 70)             0
#
#  lstm_1 (LSTM)               (None, 35)                14840
#
#  dense (Dense)               (None, 3)                 108
#
# =================================================================
# Total params: 38188 (149.17 KB)
# Trainable params: 38188 (149.17 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
#
#
# Snake model summary
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 1, 128)            72192
#
#  dropout_1 (Dropout)         (None, 1, 128)            0
#
#  lstm_3 (LSTM)               (None, 64)                49408
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 121795 (475.76 KB)
# Trainable params: 121795 (475.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
snake_y_pred = snake_model.predict(X_test)
snake_y_pred_classes = np.argmax(snake_y_pred, axis=1)

ga_y_pred = ga_model.predict(X_test)
ga_y_pred_classes = np.argmax(ga_y_pred, axis=1)

# Create a confusion matrix
snake_cm = confusion_matrix(y_test, snake_y_pred_classes)
ga_cm = confusion_matrix(y_test, ga_y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(snake_cm, annot=True, fmt='g', cmap='Blues', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.title('Snake Algorithm Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


plt.figure(figsize=(8, 6))
sns.heatmap(ga_cm, annot=True, fmt='g', cmap='Blues', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.title('Genitic Algorithm Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 2ms/step

# %%
# ga_model.save('../models/ga_model_95.keras')
# snake_model.save('../models/snake_model_88.keras')

# %% [markdown]
# # SNAKE ALGORITHM

# %%
# Define the Search Space
units = [32, 64, 128]
dropout_rates = [0.1, 0.2, 0.3]
learning_rates = [0.001, 0.005]
batch_sizes = [32, 64]

# Initial Random Selection from Search Space
current_hyperparameters = {
    "units": np.random.choice(units),
    "dropout_rate": np.random.choice(dropout_rates),
    "learning_rate": np.random.choice(learning_rates),
    "batch_size": np.random.choice(batch_sizes)
}

# Store the best hyperparameters and accuracy
best_hyperparameters = None
best_accuracy = 0

# Function to train a model with given hyperparameters

# SOA Loop
for iteration in range(10):
    _,hist = trainModel(current_hyperparameters)
    accuracy=hist.history["accuracy"][-1]
    # Update best hyperparameters if better ones are found
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_hyperparameters = current_hyperparameters.copy()

        # Greedy Exploitation: Refine search around the best hyperparameters
        # Here, we're perturbing the hyperparameters slightly
        current_hyperparameters = {
            "units": max(32, best_hyperparameters["units"] + np.random.choice([-16, 16])),
            "dropout_rate": min(0.3, max(0.1, best_hyperparameters["dropout_rate"] + np.random.choice([-0.1, 0.1]))),
            "learning_rate": min(0.005, max(0.001, best_hyperparameters["learning_rate"] * np.random.choice([0.5, 1.5]))),
            "batch_size": max(32, best_hyperparameters["batch_size"] + np.random.choice([-16, 16]))
        }
    else:
        # Random Exploration
        current_hyperparameters = {
            "units": np.random.choice(units),
            "dropout_rate": np.random.choice(dropout_rates),
            "learning_rate": np.random.choice(learning_rates),
            "batch_size": np.random.choice(batch_sizes)
        }

print("Best Hyperparameters:", best_hyperparameters)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 10s 95ms/step - loss: 0.8017 - accuracy: 0.6769 - val_loss: 0.5745 - val_accuracy: 0.7500
# Epoch 2/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.5366 - accuracy: 0.7725 - val_loss: 0.4700 - val_accuracy: 0.8000
# Epoch 3/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4923 - accuracy: 0.7994 - val_loss: 0.4651 - val_accuracy: 0.8025
# Epoch 4/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.4842 - accuracy: 0.7912 - val_loss: 0.4472 - val_accuracy: 0.8025
# Epoch 5/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.
100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3764 - accuracy: 0.8306 - val_loss: 0.4304 - val_accuracy: 0.7975
# Epoch 90/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.3926 - accuracy: 0.8263 - val_loss: 0.4243 - val_accuracy: 0.8150
# Epoch 91/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.3751 - accuracy: 0.8369 - val_loss: 0.4256 - val_accuracy: 0.8075
# Epoch 92/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3702 - accuracy: 0.8381 - val_loss: 0.4353 - val_accuracy: 0.8050
# Epoch 93/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3939 - accuracy: 0.8300 - val_loss: 0.4236 - val_accuracy: 0.8025
# Epoch 94/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3805 - accuracy: 0.8363 - val_loss: 0.4513 - val_accuracy: 0.7900
# Epoch 95/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.3745 - accuracy: 0.8363 - val_loss: 0.4243 - val_accuracy: 0.8050
# Epoch 96/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3844 - accuracy: 0.8388 - val_loss: 0.4328 - val_accuracy: 0.8050
# Epoch 97/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3912 - accuracy: 0.8244 - val_loss: 0.4472 - val_accuracy: 0.7975
# Epoch 98/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3780 - accuracy: 0.8338 - val_loss: 0.4484 - val_accuracy: 0.8050
# Epoch 99/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3803 - accuracy: 0.8413 - val_loss: 0.4451 - val_accuracy: 0.7950
# Epoch 100/100
# 34/34 [==============================] - 0s 9ms/step - loss: 0.3823 - accuracy: 0.8331 - val_loss: 0.4416 - val_accuracy: 0.8075
# Epoch 1/100
# 25/25 [==============================] - 7s 64ms/step - loss: 1.0859 - accuracy: 0.3738 - val_loss: 1.0582 - val_accuracy: 0.5300
# Epoch 2/100
# 25/25 [==============================] - 0s 8ms/step - loss: 1.0373 - accuracy: 0.6025 - val_loss: 1.0107 - val_accuracy: 0.6775
# Epoch 3/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.9838 - accuracy: 0.6775 - val_loss: 0.9381 - val_accuracy: 0.7125
# Epoch 4/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.8983 - accuracy: 0.7225 - val_loss: 0.8297 - val_accuracy: 0.7475
# Epoch 5/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.7934 - accuracy: 0.7344 - val_loss: 0.7243 - val_accuracy: 0.7375
# Epoch 6/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.7034 - accuracy: 0.7394 - val_loss: 0.6452 - val_accuracy: 0.7575
# Epoch 7/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6304 - accuracy: 0.7638 - val_loss: 0.5876 - val_accuracy: 0.7600
# Epoch 8/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5984 - accuracy: 0.7588 - val_loss: 0.5698 - val_accuracy: 0.7525
# Epoch 9/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5750 - accuracy: 0.7700 - val_loss: 0.5471 - val_accuracy: 0.7675
# Epoch 10/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.5561 - accuracy: 0.7688 - val_loss: 0.5304 - val_accuracy: 0.7825
# Epoch 11/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5399 - accuracy: 0.7850 - val_loss: 0.5184 - val_accuracy: 0.7900
# Epoch 12/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5248 - accuracy: 0.7881 - val_loss: 0.5062 - val_accuracy: 0.7825
# Epoch 13/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5165 - accuracy: 0.7975 - val_loss: 0.4934 - val_accuracy: 0.7825
# Epoch 14/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4952 - accuracy: 0.7975 - val_loss: 0.4876 - val_accuracy: 0.7975
# Epoch 15/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.5049 - accuracy: 0.7894 - val_loss: 0.4814 - val_accuracy: 0.7925
# Epoch 16/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4870 - accuracy: 0.8019 - val_loss: 0.4828 - val_accuracy: 0.7975
# Epoch 17/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4822 - accuracy: 0.7969 - val_loss: 0.4708 - val_accuracy: 0.7975
# Epoch 18/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4790 - accuracy: 0.8006 - val_loss: 0.4792 - val_accuracy: 0.7900
# Epoch 19/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4814 - accuracy: 0.7931 - val_loss: 0.4671 - val_accuracy: 0.7950
# Epoch 20/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4708 - accuracy: 0.8025 - val_loss: 0.4691 - val_accuracy: 0.8025
# Epoch 21/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4730 - accuracy: 0.7987 - val_loss: 0.4595 - val_accuracy: 0.8075
# Epoch 22/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4719 - accuracy: 0.8112 - val_loss: 0.4513 - val_accuracy: 0.8000
# Epoch 23/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4679 - accuracy: 0.8069 - val_loss: 0.4491 - val_accuracy: 0.8075
# Epoch 24/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4604 - accuracy: 0.8025 - val_loss: 0.4527 - val_accuracy: 0.7950
# Epoch 25/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4690 - accuracy: 0.8163 - val_loss: 0.4500 - val_accuracy: 0.8000
# Epoch 26/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4438 - accuracy: 0.8056 - val_loss: 0.4457 - val_accuracy: 0.8050
# Epoch 27/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4517 - accuracy: 0.8075 - val_loss: 0.4464 - val_accuracy: 0.8025
# Epoch 28/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4515 - accuracy: 0.8144 - val_loss: 0.4368 - val_accuracy: 0.8200
# Epoch 29/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4588 - accuracy: 0.8150 - val_loss: 0.4511 - val_accuracy: 0.8025
# Epoch 30/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4556 - accuracy: 0.8144 - val_loss: 0.4430 - val_accuracy: 0.8100
# Epoch 31/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4417 - accuracy: 0.8181 - val_loss: 0.4447 - val_accuracy: 0.8025
# Epoch 32/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4330 - accuracy: 0.8231 - val_loss: 0.4357 - val_accuracy: 0.8075
# Epoch 33/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4400 - accuracy: 0.8156 - val_loss: 0.4405 - val_accuracy: 0.8025
# Epoch 34/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4394 - accuracy: 0.8181 - val_loss: 0.4444 - val_accuracy: 0.7950
# Epoch 35/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4413 - accuracy: 0.8156 - val_loss: 0.4462 - val_accuracy: 0.7975
# Epoch 36/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.4388 - accuracy: 0.8100 - val_loss: 0.4481 - val_accuracy: 0.8025
# Epoch 37/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4216 - accuracy: 0.8306 - val_loss: 0.4494 - val_accuracy: 0.8025
# Epoch 38/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4470 - accuracy: 0.8163 - val_loss: 0.4331 - val_accuracy: 0.8100
# Epoch 39/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4373 - accuracy: 0.8106 - val_loss: 0.4346 - val_accuracy: 0.8050
# Epoch 40/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4324 - accuracy: 0.8206 - val_loss: 0.4331 - val_accuracy: 0.7975
# Epoch 41/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4367 - accuracy: 0.8206 - val_loss: 0.4411 - val_accuracy: 0.8000
# Epoch 42/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4294 - accuracy: 0.8238 - val_loss: 0.4348 - val_accuracy: 0.7975
# Epoch 43/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4370 - accuracy: 0.8188 - val_loss: 0.4376 - val_accuracy: 0.7975
# Epoch 44/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4438 - accuracy: 0.8131 - val_loss: 0.4320 - val_accuracy: 0.8025
# Epoch 45/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4344 - accuracy: 0.8156 - val_loss: 0.4380 - val_accuracy: 0.8075
# Epoch 46/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4209 - accuracy: 0.8250 - val_loss: 0.4393 - val_accuracy: 0.7950
# Epoch 47/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4338 - accuracy: 0.8219 - val_loss: 0.4383 - val_accuracy: 0.8000
# Epoch 48/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4283 - accuracy: 0.8200 - val_loss: 0.4351 - val_accuracy: 0.7975
# Epoch 49/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4094 - accuracy: 0.8313 - val_loss: 0.4298 - val_accuracy: 0.8000
# Epoch 50/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4150 - accuracy: 0.8313 - val_loss: 0.4409 - val_accuracy: 0.8050
# Epoch 51/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4264 - accuracy: 0.8238 - val_loss: 0.4403 - val_accuracy: 0.7950
# Epoch 52/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4182 - accuracy: 0.8275 - val_loss: 0.4417 - val_accuracy: 0.7950
# Epoch 53/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4285 - accuracy: 0.8219 - val_loss: 0.4388 - val_accuracy: 0.8025
# Epoch 54/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4384 - accuracy: 0.8150 - val_loss: 0.4387 - val_accuracy: 0.8025
# Epoch 55/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4118 - accuracy: 0.8188 - val_loss: 0.4356 - val_accuracy: 0.8025
# Epoch 56/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4327 - accuracy: 0.8163 - val_loss: 0.4333 - val_accuracy: 0.8050
# Epoch 57/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4147 - accuracy: 0.8263 - val_loss: 0.4385 - val_accuracy: 0.7925
# Epoch 58/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4175 - accuracy: 0.8256 - val_loss: 0.4354 - val_accuracy: 0.8025
# Epoch 59/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4154 - accuracy: 0.8319 - val_loss: 0.4354 - val_accuracy: 0.8050
# Epoch 60/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4248 - accuracy: 0.8300 - val_loss: 0.4334 - val_accuracy: 0.8000
# Epoch 61/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4120 - accuracy: 0.8263 - val_loss: 0.4382 - val_accuracy: 0.7875
# Epoch 62/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4162 - accuracy: 0.8306 - val_loss: 0.4404 - val_accuracy: 0.7875
# Epoch 63/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4127 - accuracy: 0.8250 - val_loss: 0.4359 - val_accuracy: 0.8025
# Epoch 64/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4209 - accuracy: 0.8225 - val_loss: 0.4381 - val_accuracy: 0.7950
# Epoch 65/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4261 - accuracy: 0.8300 - val_loss: 0.4413 - val_accuracy: 0.7950
# Epoch 66/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4092 - accuracy: 0.8269 - val_loss: 0.4391 - val_accuracy: 0.7975
# Epoch 67/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4148 - accuracy: 0.8281 - val_loss: 0.4431 - val_accuracy: 0.7925
# Epoch 68/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4183 - accuracy: 0.8281 - val_loss: 0.4451 - val_accuracy: 0.7925
# Epoch 69/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4250 - accuracy: 0.8244 - val_loss: 0.4446 - val_accuracy: 0.8000
# Epoch 70/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4112 - accuracy: 0.8331 - val_loss: 0.4414 - val_accuracy: 0.7925
# Epoch 71/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4042 - accuracy: 0.8281 - val_loss: 0.4493 - val_accuracy: 0.7875
# Epoch 72/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4219 - accuracy: 0.8213 - val_loss: 0.4412 - val_accuracy: 0.7875
# Epoch 73/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4041 - accuracy: 0.8331 - val_loss: 0.4519 - val_accuracy: 0.7975
# Epoch 74/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4014 - accuracy: 0.8288 - val_loss: 0.4511 - val_accuracy: 0.7950
# Epoch 75/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4107 - accuracy: 0.8331 - val_loss: 0.4391 - val_accuracy: 0.8025
# Epoch 76/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4101 - accuracy: 0.8188 - val_loss: 0.4429 - val_accuracy: 0.7900
# Epoch 77/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4140 - accuracy: 0.8206 - val_loss: 0.4467 - val_accuracy: 0.7925
# Epoch 78/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4125 - accuracy: 0.8200 - val_loss: 0.4402 - val_accuracy: 0.7950
# Epoch 79/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4016 - accuracy: 0.8375 - val_loss: 0.4408 - val_accuracy: 0.7975
# Epoch 80/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4027 - accuracy: 0.8344 - val_loss: 0.4348 - val_accuracy: 0.8000
# Epoch 81/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3980 - accuracy: 0.8413 - val_loss: 0.4375 - val_accuracy: 0.8025
# Epoch 82/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3930 - accuracy: 0.8269 - val_loss: 0.4441 - val_accuracy: 0.7925
# Epoch 83/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3988 - accuracy: 0.8313 - val_loss: 0.4427 - val_accuracy: 0.7925
# Epoch 84/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.4023 - accuracy: 0.8275 - val_loss: 0.4448 - val_accuracy: 0.7975
# Epoch 85/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4019 - accuracy: 0.8344 - val_loss: 0.4374 - val_accuracy: 0.8025
# Epoch 86/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4058 - accuracy: 0.8363 - val_loss: 0.4384 - val_accuracy: 0.8075
# Epoch 87/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3996 - accuracy: 0.8263 - val_loss: 0.4442 - val_accuracy: 0.7950
# Epoch 88/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3968 - accuracy: 0.8275 - val_loss: 0.4392 - val_accuracy: 0.8000
# Epoch 89/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3993 - accuracy: 0.8300 - val_loss: 0.4388 - val_accuracy: 0.8100
# Epoch 90/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4078 - accuracy: 0.8288 - val_loss: 0.4387 - val_accuracy: 0.7950
# Epoch 91/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4137 - accuracy: 0.8175 - val_loss: 0.4375 - val_accuracy: 0.7975
# Epoch 92/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4059 - accuracy: 0.8313 - val_loss: 0.4300 - val_accuracy: 0.7975
# Epoch 93/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3959 - accuracy: 0.8256 - val_loss: 0.4343 - val_accuracy: 0.8025
# Epoch 94/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4049 - accuracy: 0.8406 - val_loss: 0.4364 - val_accuracy: 0.8025
# Epoch 95/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3969 - accuracy: 0.8388 - val_loss: 0.4377 - val_accuracy: 0.8025
# Epoch 96/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3968 - accuracy: 0.8381 - val_loss: 0.4382 - val_accuracy: 0.8050
# Epoch 97/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4102 - accuracy: 0.8194 - val_loss: 0.4356 - val_accuracy: 0.8050
# Epoch 98/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3952 - accuracy: 0.8375 - val_loss: 0.4308 - val_accuracy: 0.8025
# Epoch 99/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3937 - accuracy: 0.8325 - val_loss: 0.4365 - val_accuracy: 0.8075
# Epoch 100/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3891 - accuracy: 0.8375 - val_loss: 0.4387 - val_accuracy: 0.7875
# Epoch 1/100
# 25/25 [==============================] - 7s 61ms/step - loss: 0.9090 - accuracy: 0.6637 - val_loss: 0.7235 - val_accuracy: 0.7450
# Epoch 2/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.6256 - accuracy: 0.7531 - val_loss: 0.5530 - val_accuracy: 0.7550
# Epoch 3/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.5245 - accuracy: 0.7806 - val_loss: 0.4968 - val_accuracy: 0.7750
# Epoch 4/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.4720 - accuracy: 0.8000 - val_loss: 0.4519 - val_accuracy: 0.7825
# Epoch 5/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4493 - accuracy: 0.8150 - val_loss: 0.4392 - val_accuracy: 0.8125
# Epoch 6/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4299 - accuracy: 0.8269 - val_loss: 0.4435 - val_accuracy: 0.7975
# Epoch 7/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4285 - accuracy: 0.8169 - val_loss: 0.4357 - val_accuracy: 0.7950
# Epoch 8/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.4182 - accuracy: 0.8219 - val_loss: 0.4311 - val_accuracy: 0.7950
# Epoch 9/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.4170 - accuracy: 0.8188 - val_loss: 0.4148 - val_accuracy: 0.8050
# Epoch 10/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.4028 - accuracy: 0.8338 - val_loss: 0.4275 - val_accuracy: 0.8125
# Epoch 11/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.4134 - accuracy: 0.8238 - val_loss: 0.4232 - val_accuracy: 0.8125
# Epoch 12/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4046 - accuracy: 0.8238 - val_loss: 0.4047 - val_accuracy: 0.8150
# Epoch 13/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3961 - accuracy: 0.8338 - val_loss: 0.4249 - val_accuracy: 0.8075
# Epoch 14/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3939 - accuracy: 0.8288 - val_loss: 0.4162 - val_accuracy: 0.8075
# Epoch 15/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3947 - accuracy: 0.8325 - val_loss: 0.4082 - val_accuracy: 0.8275
# Epoch 16/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3972 - accuracy: 0.8244 - val_loss: 0.4100 - val_accuracy: 0.8150
# Epoch 17/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.3988 - accuracy: 0.8288 - val_loss: 0.4352 - val_accuracy: 0.8000
# Epoch 18/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4025 - accuracy: 0.8344 - val_loss: 0.4040 - val_accuracy: 0.8175
# Epoch 19/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3942 - accuracy: 0.8375 - val_loss: 0.4125 - val_accuracy: 0.8050
# Epoch 20/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3877 - accuracy: 0.8319 - val_loss: 0.4080 - val_accuracy: 0.8150
# Epoch 21/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.3935 - accuracy: 0.8300 - val_loss: 0.4149 - val_accuracy: 0.8050
# Epoch 22/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3869 - accuracy: 0.8319 - val_loss: 0.3966 - val_accuracy: 0.8025
# Epoch 23/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.3891 - accuracy: 0.8350 - val_loss: 0.4317 - val_accuracy: 0.8100
# Epoch 24/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3812 - accuracy: 0.8438 - val_loss: 0.4051 - val_accuracy: 0.8025
# Epoch 25/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3833 - accuracy: 0.8369 - val_loss: 0.4014 - val_accuracy: 0.8075
# Epoch 26/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3779 - accuracy: 0.8381 - val_loss: 0.3944 - val_accuracy: 0.8075
# Epoch 27/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.3809 - accuracy: 0.8413 - val_loss: 0.3929 - val_accuracy: 0.8075
# Epoch 28/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.3731 - accuracy: 0.8363 - val_loss: 0.3967 - val_accuracy: 0.8250
# Epoch 29/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3808 - accuracy: 0.8369 - val_loss: 0.3929 - val_accuracy: 0.8250
# Epoch 30/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.3759 - accuracy: 0.8438 - val_loss: 0.3933 - val_accuracy: 0.8150
# Epoch 31/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.3753 - accuracy: 0.8363 - val_loss: 0.4082 - val_accuracy: 0.8100
# Epoch 32/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3687 - accuracy: 0.8456 - val_loss: 0.4072 - val_accuracy: 0.8125
# Epoch 33/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.3695 - accuracy: 0.8331 - val_loss: 0.3948 - val_accuracy: 0.8200
# Epoch 34/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3624 - accuracy: 0.8394 - val_loss: 0.3968 - val_accuracy: 0.8275
# Epoch 35/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3648 - accuracy: 0.8462 - val_loss: 0.3972 - val_accuracy: 0.8275
# Epoch 36/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.3680 - accuracy: 0.8406 - val_loss: 0.4119 - val_accuracy: 0.8100
# Epoch 37/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.3635 - accuracy: 0.8500 - val_loss: 0.3986 - val_accuracy: 0.8275
# Epoch 38/100
# ...
# 25/25 [==============================] - 0s 7ms/step - loss: 0.3605 - accuracy: 0.8444 - val_loss: 0.4232 - val_accuracy: 0.8075
# Epoch 90/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.3739 - accuracy: 0.8350 - val_loss: 0.4592 - val_accuracy: 0.8000
# Epoch 91/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.3818 - accuracy: 0.8294 - val_loss: 0.4568 - val_accuracy: 0.8125
# Epoch 92/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.3787 - accuracy: 0.8388 - val_loss: 0.4356 - val_accuracy: 0.8025
# Epoch 93/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.3741 - accuracy: 0.8394 - val_loss: 0.4351 - val_accuracy: 0.8200
# Epoch 94/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.3617 - accuracy: 0.8456 - val_loss: 0.4431 - val_accuracy: 0.8000
# Epoch 95/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3598 - accuracy: 0.8444 - val_loss: 0.4419 - val_accuracy: 0.7925
# Epoch 96/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.3665 - accuracy: 0.8375 - val_loss: 0.4447 - val_accuracy: 0.8025
# Epoch 97/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3701 - accuracy: 0.8381 - val_loss: 0.4384 - val_accuracy: 0.7975
# Epoch 98/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.3791 - accuracy: 0.8400 - val_loss: 0.4370 - val_accuracy: 0.7925
# Epoch 99/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.3630 - accuracy: 0.8425 - val_loss: 0.4269 - val_accuracy: 0.8050
# Epoch 100/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.3659 - accuracy: 0.8462 - val_loss: 0.4333 - val_accuracy: 0.8125
# Epoch 1/100
# 25/25 [==============================] - 7s 51ms/step - loss: 0.9350 - accuracy: 0.5750 - val_loss: 0.7631 - val_accuracy: 0.7075
# Epoch 2/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6620 - accuracy: 0.7294 - val_loss: 0.5598 - val_accuracy: 0.7650
# Epoch 3/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.5734 - accuracy: 0.7544 - val_loss: 0.5297 - val_accuracy: 0.7375
# Epoch 4/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.5780 - accuracy: 0.7563 - val_loss: 0.4987 - val_accuracy: 0.7725
# Epoch 5/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5318 - accuracy: 0.7831 - val_loss: 0.4935 - val_accuracy: 0.7825
# Epoch 6/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5299 - accuracy: 0.7781 - val_loss: 0.4902 - val_accuracy: 0.7775
# Epoch 7/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5165 - accuracy: 0.7744 - val_loss: 0.4898 - val_accuracy: 0.7750
# Epoch 8/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5107 - accuracy: 0.7900 - val_loss: 0.4861 - val_accuracy: 0.7800
# Epoch 9/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5190 - accuracy: 0.7750 - val_loss: 0.4860 - val_accuracy: 0.7825
# Epoch 10/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4859 - accuracy: 0.7869 - val_loss: 0.4563 - val_accuracy: 0.7825
# Epoch 11/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4797 - accuracy: 0.8044 - val_loss: 0.4453 - val_accuracy: 0.8100
# Epoch 12/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4768 - accuracy: 0.7969 - val_loss: 0.4667 - val_accuracy: 0.7825
# Epoch 13/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.4761 - accuracy: 0.8044 - val_loss: 0.4533 - val_accuracy: 0.8075
# Epoch 14/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4879 - accuracy: 0.7956 - val_loss: 0.4377 - val_accuracy: 0.7925
# Epoch 15/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4835 - accuracy: 0.7912 - val_loss: 0.4348 - val_accuracy: 0.8200
# Epoch 16/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.4722 - accuracy: 0.8031 - val_loss: 0.4487 - val_accuracy: 0.8175
# Epoch 17/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4645 - accuracy: 0.7981 - val_loss: 0.4512 - val_accuracy: 0.7925
# Epoch 18/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4576 - accuracy: 0.8012 - val_loss: 0.4415 - val_accuracy: 0.8000
# Epoch 19/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4792 - accuracy: 0.7925 - val_loss: 0.4501 - val_accuracy: 0.8000
# Epoch 20/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4573 - accuracy: 0.8081 - val_loss: 0.4379 - val_accuracy: 0.7850
# Epoch 21/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4698 - accuracy: 0.7975 - val_loss: 0.4419 - val_accuracy: 0.8050
# Epoch 22/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4689 - accuracy: 0.8119 - val_loss: 0.4371 - val_accuracy: 0.7975
# Epoch 23/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4436 - accuracy: 0.8131 - val_loss: 0.4437 - val_accuracy: 0.7975
# Epoch 24/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4558 - accuracy: 0.8125 - val_loss: 0.4323 - val_accuracy: 0.8050
# Epoch 25/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4522 - accuracy: 0.8094 - val_loss: 0.4667 - val_accuracy: 0.7950
# Epoch 26/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.4569 - accuracy: 0.8119 - val_loss: 0.4380 - val_accuracy: 0.8175
# Epoch 27/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4530 - accuracy: 0.8069 - val_loss: 0.4354 - val_accuracy: 0.8100
# Epoch 28/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4511 - accuracy: 0.8119 - val_loss: 0.4377 - val_accuracy: 0.8125
# Epoch 29/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4445 - accuracy: 0.8106 - val_loss: 0.4264 - val_accuracy: 0.8275
# Epoch 30/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4517 - accuracy: 0.8062 - val_loss: 0.4456 - val_accuracy: 0.8050
# Epoch 31/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4330 - accuracy: 0.8144 - val_loss: 0.4318 - val_accuracy: 0.7975
# Epoch 32/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4407 - accuracy: 0.8081 - val_loss: 0.4375 - val_accuracy: 0.8075
# Epoch 33/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4563 - accuracy: 0.8031 - val_loss: 0.4301 - val_accuracy: 0.8075
# Epoch 34/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4680 - accuracy: 0.8031 - val_loss: 0.4353 - val_accuracy: 0.8050
# Epoch 35/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4489 - accuracy: 0.8081 - val_loss: 0.4296 - val_accuracy: 0.8200
# Epoch 36/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4466 - accuracy: 0.8081 - val_loss: 0.4545 - val_accuracy: 0.7825
# Epoch 37/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4590 - accuracy: 0.8000 - val_loss: 0.4373 - val_accuracy: 0.7975
# Epoch 38/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4420 - accuracy: 0.8119 - val_loss: 0.4298 - val_accuracy: 0.8050
# Epoch 39/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4456 - accuracy: 0.8062 - val_loss: 0.4234 - val_accuracy: 0.8125
# Epoch 40/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4447 - accuracy: 0.8006 - val_loss: 0.4270 - val_accuracy: 0.8050
# Epoch 41/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.4317 - accuracy: 0.8156 - val_loss: 0.4435 - val_accuracy: 0.8025
# Epoch 42/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4439 - accuracy: 0.8138 - val_loss: 0.4266 - val_accuracy: 0.8025
# Epoch 43/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4252 - accuracy: 0.8181 - val_loss: 0.4330 - val_accuracy: 0.7975
# Epoch 44/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4462 - accuracy: 0.8131 - val_loss: 0.4332 - val_accuracy: 0.8075
# Epoch 45/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4295 - accuracy: 0.8188 - val_loss: 0.4263 - val_accuracy: 0.8200
# Epoch 46/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4291 - accuracy: 0.8213 - val_loss: 0.4233 - val_accuracy: 0.8150
# Epoch 47/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4253 - accuracy: 0.8325 - val_loss: 0.4238 - val_accuracy: 0.8050
# Epoch 48/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.4396 - accuracy: 0.8144 - val_loss: 0.4159 - val_accuracy: 0.8300
# Epoch 49/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4418 - accuracy: 0.8119 - val_loss: 0.4272 - val_accuracy: 0.8225
# Epoch 50/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4361 - accuracy: 0.8156 - val_loss: 0.4283 - val_accuracy: 0.7975
# Epoch 51/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4471 - accuracy: 0.8119 - val_loss: 0.4229 - val_accuracy: 0.8200
# Epoch 52/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4394 - accuracy: 0.8144 - val_loss: 0.4336 - val_accuracy: 0.7900
# Epoch 53/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4293 - accuracy: 0.8294 - val_loss: 0.4428 - val_accuracy: 0.8025
# Epoch 54/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4595 - accuracy: 0.8044 - val_loss: 0.4279 - val_accuracy: 0.8075
# Epoch 55/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4410 - accuracy: 0.8156 - val_loss: 0.4311 - val_accuracy: 0.7900
# Epoch 56/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4335 - accuracy: 0.8081 - val_loss: 0.4441 - val_accuracy: 0.8225
# Epoch 57/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4463 - accuracy: 0.8062 - val_loss: 0.4161 - val_accuracy: 0.8125
# Epoch 58/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4522 - accuracy: 0.8138 - val_loss: 0.4378 - val_accuracy: 0.8075
# Epoch 59/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4285 - accuracy: 0.8156 - val_loss: 0.4247 - val_accuracy: 0.8125
# Epoch 60/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4324 - accuracy: 0.8225 - val_loss: 0.4322 - val_accuracy: 0.8125
# Epoch 61/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4487 - accuracy: 0.8106 - val_loss: 0.4268 - val_accuracy: 0.8075
# Epoch 62/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4426 - accuracy: 0.8056 - val_loss: 0.4318 - val_accuracy: 0.8075
# Epoch 63/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4267 - accuracy: 0.8219 - val_loss: 0.4409 - val_accuracy: 0.7975
# Epoch 64/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4311 - accuracy: 0.8100 - val_loss: 0.4218 - val_accuracy: 0.8125
# Epoch 65/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4187 - accuracy: 0.8112 - val_loss: 0.4244 - val_accuracy: 0.8075
# Epoch 66/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.4202 - accuracy: 0.8225 - val_loss: 0.4237 - val_accuracy: 0.8100
# Epoch 67/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4299 - accuracy: 0.8006 - val_loss: 0.4389 - val_accuracy: 0.7925
# Epoch 68/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4386 - accuracy: 0.8094 - val_loss: 0.4179 - val_accuracy: 0.8150
# Epoch 69/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4399 - accuracy: 0.8206 - val_loss: 0.4136 - val_accuracy: 0.8200
# Epoch 70/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4220 - accuracy: 0.8206 - val_loss: 0.4214 - val_accuracy: 0.8175
# Epoch 71/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4179 - accuracy: 0.8231 - val_loss: 0.4299 - val_accuracy: 0.8000
# Epoch 72/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4172 - accuracy: 0.8213 - val_loss: 0.4265 - val_accuracy: 0.7925
# Epoch 73/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4199 - accuracy: 0.8225 - val_loss: 0.4008 - val_accuracy: 0.8075
# Epoch 74/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4300 - accuracy: 0.8206 - val_loss: 0.4306 - val_accuracy: 0.8150
# Epoch 75/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4197 - accuracy: 0.8250 - val_loss: 0.4262 - val_accuracy: 0.8150
# Epoch 76/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4214 - accuracy: 0.8281 - val_loss: 0.4484 - val_accuracy: 0.8000
# Epoch 77/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4171 - accuracy: 0.8238 - val_loss: 0.4351 - val_accuracy: 0.8100
# Epoch 78/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4231 - accuracy: 0.8219 - val_loss: 0.4141 - val_accuracy: 0.8050
# Epoch 79/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4049 - accuracy: 0.8344 - val_loss: 0.4414 - val_accuracy: 0.7925
# Epoch 80/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4166 - accuracy: 0.8269 - val_loss: 0.4198 - val_accuracy: 0.8100
# Epoch 81/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.4237 - accuracy: 0.8087 - val_loss: 0.4325 - val_accuracy: 0.8100
# Epoch 82/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4205 - accuracy: 0.8231 - val_loss: 0.4344 - val_accuracy: 0.7975
# Epoch 83/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4030 - accuracy: 0.8275 - val_loss: 0.4381 - val_accuracy: 0.8000
# Epoch 84/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4266 - accuracy: 0.8244 - val_loss: 0.4291 - val_accuracy: 0.8050
# Epoch 85/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4164 - accuracy: 0.8200 - val_loss: 0.4358 - val_accuracy: 0.8050
# Epoch 86/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4164 - accuracy: 0.8181 - val_loss: 0.4211 - val_accuracy: 0.8125
# Epoch 87/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4178 - accuracy: 0.8263 - val_loss: 0.4379 - val_accuracy: 0.8050
# Epoch 88/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4135 - accuracy: 0.8200 - val_loss: 0.4420 - val_accuracy: 0.7875
# Epoch 89/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4076 - accuracy: 0.8138 - val_loss: 0.4404 - val_accuracy: 0.7925
# Epoch 90/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4073 - accuracy: 0.8250 - val_loss: 0.4314 - val_accuracy: 0.7975
# Epoch 91/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4169 - accuracy: 0.8238 - val_loss: 0.4374 - val_accuracy: 0.7950
# Epoch 92/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4039 - accuracy: 0.8269 - val_loss: 0.4271 - val_accuracy: 0.8025
# Epoch 93/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4085 - accuracy: 0.8219 - val_loss: 0.4335 - val_accuracy: 0.8000
# Epoch 94/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4250 - accuracy: 0.8194 - val_loss: 0.4165 - val_accuracy: 0.8075
# Epoch 95/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4126 - accuracy: 0.8238 - val_loss: 0.4289 - val_accuracy: 0.7825
# Epoch 96/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4104 - accuracy: 0.8250 - val_loss: 0.4567 - val_accuracy: 0.8025
# Epoch 97/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4052 - accuracy: 0.8225 - val_loss: 0.4520 - val_accuracy: 0.7950
# Epoch 98/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4148 - accuracy: 0.8225 - val_loss: 0.4318 - val_accuracy: 0.8125
# Epoch 99/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4073 - accuracy: 0.8256 - val_loss: 0.4396 - val_accuracy: 0.7950
# Epoch 100/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.4083 - accuracy: 0.8288 - val_loss: 0.4271 - val_accuracy: 0.8050
# Best Hyperparameters: {'units': 144, 'dropout_rate': 0.3, 'learning_rate': 0.0015, 'batch_size': 80}

# %% [markdown]
# # GA ALGORITHM

# %%
from gaft import GAEngine
from gaft.components import individual, Population,DecimalIndividual
from gaft.operators import RouletteWheelSelection, UniformCrossover, FlipBitMutation

# Define hyperparameter ranges
hyperparameter_ranges = {
    'units': (10,100),
    'dropout_rate': (0.1, 1.0),
    'learning_rate': (0.001, 0.1),
    'batch_size': (10, 100)
}

indv_template = DecimalIndividual(ranges=list(hyperparameter_ranges.values()))

# Create population
population = Population(indv_template=indv_template, size=50).init()

# Define Genetic Algorithm operators
selection = RouletteWheelSelection()
crossover = UniformCrossover(pc=0.8, pe=0.5)
mutation = FlipBitMutation(pm=0.1)

# Create Genetic Algorithm engine
engine = GAEngine(population=population, selection=selection, crossover=crossover, mutation=mutation)

@engine.fitness_register
def fitness(indv):
    # Use hyperparameters from individual
    hyperparameters = dict(zip(hyperparameter_ranges.keys(), indv.solution))

    # Train the model with the hyperparameters
    _,hist = trainModel(hyperparameters)  # Call your trainModel function
    accuracy = max(hist.history['accuracy']) # Extract validation accuracy
    print("\nParameters: ",hyperparameters,f" accuracy: {accuracy}")
    print("\n\n\n *********************** New Generation Training Start *******************************\n ")
    return accuracy

# Run the Genetic Algorithm
engine.run(ng=5)

# Access the best individual
best_individual = engine.best_individual()
best_hyperparameters = dict(zip(hyperparameter_ranges.keys(), best_individual.solution))
print("Best hyperparameters: ", best_hyperparameters)
