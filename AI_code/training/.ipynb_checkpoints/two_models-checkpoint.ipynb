# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from keras.models import Sequential,load_model
from keras.layers import LSTM, Dense,Dropout,Bidirectional
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning, module="tensorflow")
warnings.resetwarnings()
# Out:
# WARNING:tensorflow:From C:\Users\msr\Desktop\apps\Cloud-Simulation-AI\AI_code\.venv2\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv('../dataset/distance_dataset.csv') 

X = df.drop('DataCenterID', axis=1)  # Features
y = df['DataCenterID']-3  # Label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
unique_labels = np.unique(y_train.values)
print(unique_labels)
print(df.info())
num_classes = len(unique_labels)
# Out:
# [0 1 2]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TaskFileSize        2000 non-null   int64
#  1   TaskOutputFileSize  2000 non-null   int64
#  2   TaskFileLength      2000 non-null   int64
#  3   UserLatitude        2000 non-null   float64
#  4   UserLongitude       2000 non-null   float64
#  5   DataCenterID        2000 non-null   int64
# dtypes: float64(2), int64(4)
# memory usage: 93.9 KB
# None

# %%
# sns.pairplot(df, hue='DataCenterID')
# plt.show()

# %%
data_center_labels = ['DataCenter1', 'DataCenter2', 'DataCenter3']
tasks_per_data_center = df['DataCenterID'].value_counts().sort_index()

# Assigning colors
colors = ['skyblue', 'lightgreen', 'lightcoral']

# Plotting
fig, ax = plt.subplots()
bars = ax.bar(data_center_labels, tasks_per_data_center, color=colors)

# Displaying the task counts on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Adjusting plot properties
plt.title('Task Distribution On DataCenters')
plt.xlabel('Data Centers')
plt.ylabel('Number of Tasks')
plt.ylim(0, max(tasks_per_data_center) + 50)  # Adjust y-axis limit for better visibility
plt.show()

# %%
if (len(X_train.shape)<3):
    X_train = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_test = X_test.values.reshape((X_test.shape[0], 1, X_test.shape[1]))

print(" xtrain ", X_train.shape, "\n", "ytrain ", y_train.shape, "\n", "xtest  ", X_test.shape, "\n", "ytest ", y_test.shape, "\n")
# Out:
#  xtrain  (1600, 1, 5)
#  ytrain  (1600,)
#  xtest   (400, 1, 5)
#  ytest  (400,)

# %%
def train_model_1(hyperparameters):
    # Build and train the model
    model = Sequential()
    model.add(LSTM(units=int(hyperparameters['units']), input_shape=(1, X_train.shape[2]), return_sequences=True))
    model.add(Dropout(hyperparameters['dropout_rate']))
    model.add(LSTM(units=int(hyperparameters['units']) // 2))
    model.add(Dense(units=num_classes, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=hyperparameters['learning_rate']),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    hist = model.fit(X_train, y_train,
                        epochs=100,
                        batch_size=int(hyperparameters['batch_size']),
                        validation_data=(X_test, y_test),
                       )
    return model,hist

def train_model_2(hyperparameters):
    model = Sequential()
    model.add(Bidirectional(LSTM(hyperparameters["units"], activation='tanh', return_sequences=True), input_shape=(X_train.shape[1],  5))) 
    model.add(Dropout(hyperparameters["dropout_rate"]))
    model.add(Bidirectional(LSTM(int(hyperparameters["units"]/2), activation='tanh', return_sequences=True)))
    model.add(Dropout(hyperparameters["dropout_rate"]))
    model.add(Bidirectional(LSTM(int(hyperparameters["units"]/4), activation='tanh')))
    model.add(Dropout(hyperparameters["dropout_rate"]))
    model.add(Dense(1, activation='softmax'))

    opt = Adam(learning_rate=hyperparameters["learning_rate"])
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)
    hist = model.fit(X_train, y_train,
                     epochs=100,
                     batch_size=int(hyperparameters['batch_size']),
                     validation_data=(X_test, y_test),
                     callbacks=[early_stopping])
    return model, hist


SNAKE_hyperparameters = {'units': 128, 'dropout_rate': 0.01, 'learning_rate': 0.001, 'batch_size': 32}
print(" model 1 training start ....\n")
model1,history1= train_model_1(SNAKE_hyperparameters)
print(" \n\n model 2 training start ....\n")
print(" model 2 training start ....\n")

model2,history2= train_model_2(SNAKE_hyperparameters)

model1_accuracy = max(history1.history["accuracy"])
model2_accuracy = max(history2.history["accuracy"])

# %%
print("model 1  Accuracy: ",np.round(model1_accuracy* 100) ,'%')
print("model 2 Accuracy: ",np.round(model2_accuracy* 100) ,'%')

# %%
plt.plot(history1.history['accuracy'])
plt.plot(history2.history['accuracy'])
plt.title('mode-l VS model-2 Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Model 1', 'Model 2'], loc='lower right')
plt.show()

plt.plot(history1.history['loss'])
plt.plot(history2.history['loss'])
plt.title('mode-l VS model-2 Training Losses')
plt.xlabel('Epoch')
plt.ylabel('Losess')
plt.legend(['Model 1', 'Model 2'], loc='upper right')
plt.show()

print("\n\nModel 1 model summary")
print(model1.summary())
print("\n\nModel 2 model summary")
print(model2.summary())
# Out:
# Model 1 model summary
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 128)            68608
#
#  dropout (Dropout)           (None, 1, 128)            0
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 118211 (461.76 KB)
# Trainable params: 118211 (461.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
#
#
# Model 2 model summary
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 1, 256)            137216
#  al)
#
#  dropout_1 (Dropout)         (None, 1, 256)            0
#
#  bidirectional_1 (Bidirecti  (None, 1, 128)            164352
#  onal)
#
#  dropout_2 (Dropout)         (None, 1, 128)            0
#
#  bidirectional_2 (Bidirecti  (None, 64)                41216
#  onal)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 342849 (1.31 MB)
# Trainable params: 342849 (1.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# confusing matrix

model1_y_pred = model1.predict(X_test)
model1_y_pred_classes = np.argmax(model1_y_pred, axis=1)

model2_y_pred = model2.predict(X_test)
model2_y_pred_classes = np.argmax(model2_y_pred, axis=1)

# Create a confusion matrix
model1_cm = confusion_matrix(y_test, model1_y_pred_classes)
model2_cm = confusion_matrix(y_test, model2_y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(model1_cm, annot=True, fmt='g', cmap='Blues', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.title('Model 1 Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


plt.figure(figsize=(8, 6))
sns.heatmap(model2_cm, annot=True, fmt='g', cmap='Blues', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.title('Model 2 Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 13/13 [==============================] - 2s 6ms/step
# 13/13 [==============================] - 4s 4ms/step

# %%
# model1.save('../models/model1.keras')
# model2.save('../models/model2.keras')

# %% [markdown]
# # SNAKE ALGORITHM

# %%
# Define the Search Space
units = [32, 64, 128]
dropout_rates = [0.1, 0.2, 0.3]
learning_rates = [0.001, 0.005]
batch_sizes = [32, 64]

# Initial Random Selection from Search Space
current_hyperparameters = {
    "units": np.random.choice(units),
    "dropout_rate": np.random.choice(dropout_rates),
    "learning_rate": np.random.choice(learning_rates),
    "batch_size": np.random.choice(batch_sizes)
}

# Store the best hyperparameters and accuracy
best_hyperparameters = None
best_accuracy = 0

# Function to train a model with given hyperparameters

# SOA Loop
for iteration in range(10):
    _,hist = train_model_2(current_hyperparameters)
    accuracy=hist.history["accuracy"][-1]
    # Update best hyperparameters if better ones are found
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_hyperparameters = current_hyperparameters.copy()

        # Greedy Exploitation: Refine search around the best hyperparameters
        # Here, we're perturbing the hyperparameters slightly
        current_hyperparameters = {
            "units": max(32, best_hyperparameters["units"] + np.random.choice([-16, 16])),
            "dropout_rate": min(0.3, max(0.1, best_hyperparameters["dropout_rate"] + np.random.choice([-0.1, 0.1]))),
            "learning_rate": min(0.005, max(0.001, best_hyperparameters["learning_rate"] * np.random.choice([0.5, 1.5]))),
            "batch_size": max(32, best_hyperparameters["batch_size"] + np.random.choice([-16, 16]))
        }
    else:
        # Random Exploration
        current_hyperparameters = {
            "units": np.random.choice(units),
            "dropout_rate": np.random.choice(dropout_rates),
            "learning_rate": np.random.choice(learning_rates),
            "batch_size": np.random.choice(batch_sizes)
        }

print("Best Hyperparameters:", best_hyperparameters)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 17s 87ms/step - loss: -0.4027 - accuracy: 0.3300 - val_loss: -1.3006 - val_accuracy: 0.3500
# Epoch 2/100
# 50/50 [==============================] - 0s 9ms/step - loss: -2.1565 - accuracy: 0.3300 - val_loss: -2.3519 - val_accuracy: 0.3500
# Epoch 3/100
# 50/50 [==============================] - 1s 15ms/step - loss: -3.3459 - accuracy: 0.3300 - val_loss: -3.1807 - val_accuracy: 0.3500
# Epoch 4/100
# 50/50 [==============================] - 1s 16ms/step - loss: -4.4262 - accuracy: 0.3300 - val_loss: -4.2947 - val_accuracy: 0.3500
# Epoch 5/100
# 50/50 [==============================] - 1s 15ms/step - loss: -5.5051 - accuracy: 0.3300 - val_loss: -5.0645 - val_accuracy: 0.3500
# Epoch 6/100
# 50/50 [==============================] - 1s 16ms/step - loss: -6.5684 - accuracy: 0.3300 - val_loss: -5.7816 - val_accuracy: 0.3500
# Epoch 7/100
# 50/50 [==============================] - 1s 15ms/step - loss: -7.4826 - accuracy: 0.3300 - val_loss: -6.6982 - val_accuracy: 0.3500
# Epoch 8/100
# 50/50 [==============================] - 1s 13ms/step - loss: -8.4938 - accuracy: 0.3300 - val_loss: -7.4679 - val_accuracy: 0.3500
# Epoch 9/100
# 50/50 [==============================] - 1s 14ms/step - loss: -9.6034 - accuracy: 0.3300 - val_loss: -8.5067 - val_accuracy: 0.3500
# Epoch 10/100
# 50/50 [==============================] - 1s 11ms/step - loss: -10.5929 - accuracy: 0.3300 - val_loss: -9.0869 - val_accuracy: 0.3500
# Epoch 11/100
# 50/50 [==============================] - 1s 19ms/step - loss: -11.4465 - accuracy: 0.3300 - val_loss: -10.0426 - val_accuracy: 0.3500
# Epoch 12/100
# 50/50 [==============================] - 1s 18ms/step - loss: -12.5925 - accuracy: 0.3300 - val_loss: -11.0689 - val_accuracy: 0.3500
# Epoch 13/100
# 50/50 [==============================] - 0s 10ms/step - loss: -13.5525 - accuracy: 0.3300 - val_loss: -11.6949 - val_accuracy: 0.3500
# Epoch 14/100
# 50/50 [==============================] - 1s 19ms/step - loss: -14.6808 - accuracy: 0.3300 - val_loss: -12.8049 - val_accuracy: 0.3500
# Epoch 15/100
# 50/50 [==============================] - 1s 20ms/step - loss: -15.8354 - accuracy: 0.3300 - val_loss: -13.8506 - val_accuracy: 0.3500
# Epoch 16/100
# 50/50 [==============================] - 1s 14ms/step - loss: -16.4126 - accuracy: 0.3300 - val_loss: -14.5519 - val_accuracy: 0.3500
# Epoch 17/100
# 50/50 [==============================] - 1s 12ms/step - loss: -17.9132 - accuracy: 0.3300 - val_loss: -15.0605 - val_accuracy: 0.3500
# Epoch 18/100
# 50/50 [==============================] - 1s 16ms/step - loss: -18.6849 - accuracy: 0.3300 - val_loss: -15.7907 - val_accuracy: 0.3500
# Epoch 19/100
# 50/50 [==============================] - 1s 18ms/step - loss: -19.6133 - accuracy: 0.3300 - val_loss: -16.7390 - val_accuracy: 0.3500
# Epoch 20/100
# 50/50 [==============================] - 1s 12ms/step - loss: -20.9088 - accuracy: 0.3300 - val_loss: -17.6425 - val_accuracy: 0.3500
# Epoch 21/100
# 50/50 [==============================] - 1s 17ms/step - loss: -21.9622 - accuracy: 0.3300 - val_loss: -18.4214 - val_accuracy: 0.3500
# Epoch 22/100
# 50/50 [==============================] - 1s 15ms/step - loss: -22.6634 - accuracy: 0.3300 - val_loss: -19.2884 - val_accuracy: 0.3500
# Epoch 23/100
# 50/50 [==============================] - 1s 17ms/step - loss: -23.6214 - accuracy: 0.3300 - val_loss: -20.5562 - val_accuracy: 0.3500
# Epoch 24/100
# 50/50 [==============================] - 1s 17ms/step - loss: -24.9162 - accuracy: 0.3300 - val_loss: -21.6369 - val_accuracy: 0.3500
# Epoch 25/100
# 50/50 [==============================] - 1s 18ms/step - loss: -26.0859 - accuracy: 0.3300 - val_loss: -22.0063 - val_accuracy: 0.3500
# Epoch 26/100
# 50/50 [==============================] - 1s 17ms/step - loss: -26.8122 - accuracy: 0.3300 - val_loss: -22.8453 - val_accuracy: 0.3500
# Epoch 27/100
# 50/50 [==============================] - 1s 15ms/step - loss: -27.9088 - accuracy: 0.3300 - val_loss: -23.7892 - val_accuracy: 0.3500
# Epoch 28/100
# 50/50 [==============================] - 1s 13ms/step - loss: -28.7249 - accuracy: 0.3300 - val_loss: -24.8107 - val_accuracy: 0.3500
# Epoch 29/100
# 50/50 [==============================] - 1s 18ms/step - loss: -29.7927 - accuracy: 0.3300 - val_loss: -25.7897 - val_accuracy: 0.3500
# Epoch 30/100
# 50/50 [==============================] - 0s 9ms/step - loss: -31.1326 - accuracy: 0.3300 - val_loss: -26.3969 - val_accuracy: 0.3500
# Epoch 31/100
# 50/50 [==============================] - 1s 10ms/step - loss: -32.6246 - accuracy: 0.3300 - val_loss: -26.8532 - val_accuracy: 0.3500
# Epoch 32/100
# 50/50 [==============================] - 1s 18ms/step - loss: -32.9855 - accuracy: 0.3300 - val_loss: -27.1938 - val_accuracy: 0.3500
# Epoch 33/100
# 50/50 [==============================] - 1s 16ms/step - loss: -33.2894 - accuracy: 0.3300 - val_loss: -27.9120 - val_accuracy: 0.3500
# Epoch 34/100
# 50/50 [==============================] - 1s 16ms/step - loss: -35.1725 - accuracy: 0.3300 - val_loss: -29.0277 - val_accuracy: 0.3500
# Epoch 35/100
# 50/50 [==============================] - 1s 15ms/step - loss: -35.7029 - accuracy: 0.3300 - val_loss: -30.1236 - val_accuracy: 0.3500
# Epoch 36/100
# 50/50 [==============================] - 1s 16ms/step - loss: -36.7495 - accuracy: 0.3300 - val_loss: -30.9313 - val_accuracy: 0.3500
# Epoch 37/100
# 50/50 [==============================] - 1s 16ms/step - loss: -37.5101 - accuracy: 0.3300 - val_loss: -31.7669 - val_accuracy: 0.3500
# Epoch 38/100
# 50/50 [==============================] - 1s 13ms/step - loss: -39.1188 - accuracy: 0.3300 - val_loss: -33.2355 - val_accuracy: 0.3500
# Epoch 39/100
# 50/50 [==============================] - 0s 6ms/step - loss: -40.3844 - accuracy: 0.3300 - val_loss: -34.1781 - val_accuracy: 0.3500
# Epoch 40/100
# 50/50 [==============================] - 1s 18ms/step - loss: -40.9808 - accuracy: 0.3300 - val_loss: -33.9277 - val_accuracy: 0.3500
# Epoch 41/100
# 50/50 [==============================] - 1s 12ms/step - loss: -41.4673 - accuracy: 0.3300 - val_loss: -33.4316 - val_accuracy: 0.3500
# Epoch 42/100
# 50/50 [==============================] - 1s 14ms/step - loss: -42.7083 - accuracy: 0.3300 - val_loss: -35.2612 - val_accuracy: 0.3500
# Epoch 43/100
# 50/50 [==============================] - 1s 15ms/step - loss: -43.7184 - accuracy: 0.3300 - val_loss: -36.7569 - val_accuracy: 0.3500
# Epoch 44/100
# 50/50 [==============================] - 0s 7ms/step - loss: -45.7903 - accuracy: 0.3300 - val_loss: -37.9210 - val_accuracy: 0.3500
# Epoch 45/100
# 50/50 [==============================] - 1s 14ms/step - loss: -45.8063 - accuracy: 0.3300 - val_loss: -38.3084 - val_accuracy: 0.3500
# Epoch 46/100
# 50/50 [==============================] - 1s 14ms/step - loss: -46.8881 - accuracy: 0.3300 - val_loss: -39.3885 - val_accuracy: 0.3500
# Epoch 47/100
# 50/50 [==============================] - 0s 9ms/step - loss: -47.9683 - accuracy: 0.3300 - val_loss: -40.1172 - val_accuracy: 0.3500
# Epoch 48/100
# 50/50 [==============================] - 1s 12ms/step - loss: -49.5770 - accuracy: 0.3300 - val_loss: -41.0766 - val_accuracy: 0.3500
# Epoch 49/100
# 50/50 [==============================] - 0s 9ms/step - loss: -50.8638 - accuracy: 0.3300 - val_loss: -42.1393 - val_accuracy: 0.3500
# Epoch 50/100
# 50/50 [==============================] - 1s 18ms/step - loss: -50.9767 - accuracy: 0.3300 - val_loss: -42.9831 - val_accuracy: 0.3500
# Epoch 51/100
# 50/50 [==============================] - 1s 18ms/step - loss: -51.4566 - accuracy: 0.3300 - val_loss: -44.0398 - val_accuracy: 0.3500
# Epoch 52/100
# 50/50 [==============================] - 1s 15ms/step - loss: -53.0559 - accuracy: 0.3300 - val_loss: -43.9409 - val_accuracy: 0.3500
# Epoch 53/100
# 50/50 [==============================] - 1s 13ms/step - loss: -54.2544 - accuracy: 0.3300 - val_loss: -45.1768 - val_accuracy: 0.3500
# Epoch 54/100
# 50/50 [==============================] - 1s 11ms/step - loss: -54.9219 - accuracy: 0.3300 - val_loss: -47.0938 - val_accuracy: 0.3500
# Epoch 55/100
# 50/50 [==============================] - 1s 15ms/step - loss: -57.6452 - accuracy: 0.3300 - val_loss: -47.3447 - val_accuracy: 0.3500
# Epoch 56/100
# 50/50 [==============================] - 1s 16ms/step - loss: -57.6264 - accuracy: 0.3300 - val_loss: -48.6712 - val_accuracy: 0.3500
# Epoch 57/100
# 50/50 [==============================] - 1s 21ms/step - loss: -58.1773 - accuracy: 0.3300 - val_loss: -48.8954 - val_accuracy: 0.3500
# Epoch 58/100
# 50/50 [==============================] - 1s 15ms/step - loss: -59.3728 - accuracy: 0.3300 - val_loss: -50.7464 - val_accuracy: 0.3500
# Epoch 59/100
# 50/50 [==============================] - 1s 11ms/step - loss: -60.8666 - accuracy: 0.3300 - val_loss: -51.3844 - val_accuracy: 0.3500
# Epoch 60/100
# 50/50 [==============================] - 1s 18ms/step - loss: -61.9144 - accuracy: 0.3300 - val_loss: -51.8668 - val_accuracy: 0.3500
# Epoch 61/100
# 50/50 [==============================] - 1s 13ms/step - loss: -62.6119 - accuracy: 0.3300 - val_loss: -53.0782 - val_accuracy: 0.3500
# Epoch 62/100
# 50/50 [==============================] - 1s 16ms/step - loss: -64.0769 - accuracy: 0.3300 - val_loss: -52.8323 - val_accuracy: 0.3500
# Epoch 63/100
# 50/50 [==============================] - 1s 12ms/step - loss: -64.4495 - accuracy: 0.3300 - val_loss: -53.8954 - val_accuracy: 0.3500
# Epoch 64/100
# 50/50 [==============================] - 1s 15ms/step - loss: -65.8186 - accuracy: 0.3300 - val_loss: -54.0696 - val_accuracy: 0.3500
# Epoch 65/100
# 50/50 [==============================] - 1s 18ms/step - loss: -65.1618 - accuracy: 0.3300 - val_loss: -55.0144 - val_accuracy: 0.3500
# Epoch 66/100
# 50/50 [==============================] - 1s 14ms/step - loss: -67.5347 - accuracy: 0.3300 - val_loss: -55.3247 - val_accuracy: 0.3500
# Epoch 67/100
# 50/50 [==============================] - 0s 8ms/step - loss: -69.1322 - accuracy: 0.3300 - val_loss: -57.2574 - val_accuracy: 0.3500
# Epoch 68/100
# 50/50 [==============================] - 1s 17ms/step - loss: -70.3891 - accuracy: 0.3300 - val_loss: -58.6602 - val_accuracy: 0.3500
# Epoch 69/100
# 50/50 [==============================] - 1s 18ms/step - loss: -70.5332 - accuracy: 0.3300 - val_loss: -61.5637 - val_accuracy: 0.3500
# Epoch 70/100
# 50/50 [==============================] - 1s 14ms/step - loss: -71.7920 - accuracy: 0.3300 - val_loss: -61.3562 - val_accuracy: 0.3500
# Epoch 71/100
# 50/50 [==============================] - 1s 12ms/step - loss: -71.3809 - accuracy: 0.3300 - val_loss: -60.8882 - val_accuracy: 0.3500
# Epoch 72/100
# 50/50 [==============================] - 1s 16ms/step - loss: -73.9377 - accuracy: 0.3300 - val_loss: -61.0865 - val_accuracy: 0.3500
# Epoch 73/100
# 50/50 [==============================] - 1s 14ms/step - loss: -74.5976 - accuracy: 0.3300 - val_loss: -63.4980 - val_accuracy: 0.3500
# Epoch 74/100
# 50/50 [==============================] - 1s 19ms/step - loss: -74.5326 - accuracy: 0.3300 - val_loss: -65.2279 - val_accuracy: 0.3500
# Epoch 75/100
# 50/50 [==============================] - 0s 9ms/step - loss: -76.2200 - accuracy: 0.3300 - val_loss: -66.6999 - val_accuracy: 0.3500
# Epoch 76/100
# 50/50 [==============================] - 1s 16ms/step - loss: -77.2253 - accuracy: 0.3300 - val_loss: -66.7360 - val_accuracy: 0.3500
# Epoch 77/100
# 50/50 [==============================] - 0s 9ms/step - loss: -77.9789 - accuracy: 0.3300 - val_loss: -66.7664 - val_accuracy: 0.3500
# Epoch 78/100
# 50/50 [==============================] - 0s 10ms/step - loss: -80.8457 - accuracy: 0.3300 - val_loss: -66.2887 - val_accuracy: 0.3500
# Epoch 79/100
# 50/50 [==============================] - 1s 11ms/step - loss: -80.7839 - accuracy: 0.3300 - val_loss: -66.9840 - val_accuracy: 0.3500
# Epoch 80/100
# 50/50 [==============================] - 1s 16ms/step - loss: -82.9236 - accuracy: 0.3300 - val_loss: -69.4787 - val_accuracy: 0.3500
# Epoch 81/100
# 50/50 [==============================] - 1s 15ms/step - loss: -83.1013 - accuracy: 0.3300 - val_loss: -70.0908 - val_accuracy: 0.3500
# Epoch 82/100
# 50/50 [==============================] - 1s 11ms/step - loss: -83.5411 - accuracy: 0.3300 - val_loss: -69.4047 - val_accuracy: 0.3500
# Epoch 83/100
# 50/50 [==============================] - 1s 12ms/step - loss: -85.1406 - accuracy: 0.3300 - val_loss: -70.9723 - val_accuracy: 0.3500
# Epoch 84/100
# 50/50 [==============================] - 1s 16ms/step - loss: -84.9218 - accuracy: 0.3300 - val_loss: -72.6191 - val_accuracy: 0.3500
# Epoch 85/100
# 50/50 [==============================] - 0s 9ms/step - loss: -86.2313 - accuracy: 0.3300 - val_loss: -72.7726 - val_accuracy: 0.3500
# Epoch 86/100
# 50/50 [==============================] - 1s 15ms/step - loss: -87.9874 - accuracy: 0.3300 - val_loss: -73.9834 - val_accuracy: 0.3500
# Epoch 87/100
# 50/50 [==============================] - 1s 15ms/step - loss: -87.8190 - accuracy: 0.3300 - val_loss: -73.2620 - val_accuracy: 0.3500
# Epoch 88/100
# 50/50 [==============================] - 1s 16ms/step - loss: -88.9990 - accuracy: 0.3300 - val_loss: -74.7969 - val_accuracy: 0.3500
# Epoch 89/100
# 50/50 [==============================] - 1s 16ms/step - loss: -90.8748 - accuracy: 0.3300 - val_loss: -74.8989 - val_accuracy: 0.3500
# Epoch 90/100
# 50/50 [==============================] - 1s 16ms/step - loss: -90.9140 - accuracy: 0.3300 - val_loss: -76.9841 - val_accuracy: 0.3500
# Epoch 91/100
# 50/50 [==============================] - 1s 16ms/step - loss: -91.0174 - accuracy: 0.3300 - val_loss: -79.0741 - val_accuracy: 0.3500
# Epoch 92/100
# 50/50 [==============================] - 1s 16ms/step - loss: -92.8716 - accuracy: 0.3300 - val_loss: -78.8028 - val_accuracy: 0.3500
# Epoch 93/100
# 50/50 [==============================] - 1s 16ms/step - loss: -93.7321 - accuracy: 0.3300 - val_loss: -79.4991 - val_accuracy: 0.3500
# Epoch 94/100
# 50/50 [==============================] - 1s 16ms/step - loss: -95.3552 - accuracy: 0.3300 - val_loss: -80.7801 - val_accuracy: 0.3500
# Epoch 95/100
# 50/50 [==============================] - 1s 10ms/step - loss: -97.3952 - accuracy: 0.3300 - val_loss: -80.6643 - val_accuracy: 0.3500
# Epoch 96/100
# 50/50 [==============================] - 1s 16ms/step - loss: -97.4138 - accuracy: 0.3300 - val_loss: -80.3779 - val_accuracy: 0.3500
# Epoch 97/100
# 50/50 [==============================] - 1s 16ms/step - loss: -98.9741 - accuracy: 0.3300 - val_loss: -82.6818 - val_accuracy: 0.3500
# Epoch 98/100
# 50/50 [==============================] - 1s 16ms/step - loss: -98.3832 - accuracy: 0.3300 - val_loss: -82.2751 - val_accuracy: 0.3500
# Epoch 99/100
# 50/50 [==============================] - 1s 16ms/step - loss: -98.7816 - accuracy: 0.3300 - val_loss: -84.0377 - val_accuracy: 0.3500
# Epoch 100/100
# 50/50 [==============================] - 1s 15ms/step - loss: -102.4700 - accuracy: 0.3300 - val_loss: -83.7915 - val_accuracy: 0.3500
# Epoch 1/100
# 50/50 [==============================] - 20s 57ms/step - loss: -0.5193 - accuracy: 0.3300 - val_loss: -1.4989 - val_accuracy: 0.3500
# Epoch 2/100
# 50/50 [==============================] - 0s 6ms/step - loss: -2.3579 - accuracy: 0.3300 - val_loss: -2.3851 - val_accuracy: 0.3500
# Epoch 3/100
# 50/50 [==============================] - 0s 8ms/step - loss: -3.2412 - accuracy: 0.3300 - val_loss: -2.8956 - val_accuracy: 0.3500
# Epoch 4/100
# 50/50 [==============================] - 0s 10ms/step - loss: -4.0881 - accuracy: 0.3300 - val_loss: -3.8694 - val_accuracy: 0.3500
# Epoch 5/100
# 50/50 [==============================] - 0s 8ms/step - loss: -4.9100 - accuracy: 0.3300 - val_loss: -4.2899 - val_accuracy: 0.3500
# Epoch 6/100
# 50/50 [==============================] - 1s 11ms/step - loss: -5.6980 - accuracy: 0.3300 - val_loss: -4.8835 - val_accuracy: 0.3500
# Epoch 7/100
# 50/50 [==============================] - 1s 16ms/step - loss: -6.5109 - accuracy: 0.3300 - val_loss: -5.7545 - val_accuracy: 0.3500
# Epoch 8/100
# 50/50 [==============================] - 1s 17ms/step - loss: -7.3254 - accuracy: 0.3300 - val_loss: -6.4429 - val_accuracy: 0.3500
# Epoch 9/100
# 50/50 [==============================] - 0s 9ms/step - loss: -8.0434 - accuracy: 0.3300 - val_loss: -6.9755 - val_accuracy: 0.3500
# Epoch 10/100
# 50/50 [==============================] - 0s 9ms/step - loss: -8.8252 - accuracy: 0.3300 - val_loss: -7.7145 - val_accuracy: 0.3500
# Epoch 11/100
# 50/50 [==============================] - 1s 16ms/step - loss: -9.5886 - accuracy: 0.3300 - val_loss: -8.2120 - val_accuracy: 0.3500
# Epoch 12/100
# 50/50 [==============================] - 1s 16ms/step - loss: -10.3440 - accuracy: 0.3300 - val_loss: -9.1977 - val_accuracy: 0.3500
# Epoch 13/100
# 50/50 [==============================] - 1s 18ms/step - loss: -11.2387 - accuracy: 0.3300 - val_loss: -9.4746 - val_accuracy: 0.3500
# Epoch 14/100
# 50/50 [==============================] - 1s 18ms/step - loss: -11.8063 - accuracy: 0.3300 - val_loss: -10.1792 - val_accuracy: 0.3500
# Epoch 15/100
# 45/50 [==========================>...] - ETA: 0s - loss: -12.6479 - accuracy: 0.3264
